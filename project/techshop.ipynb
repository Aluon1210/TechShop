-- %% [markdown]
-- # [dbo].[Brand_Category]

-- %%
USE [Techshop]
GO

-- %%
/****** Object:  Table [dbo].[Brand_Category]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Brand_Category](
	[Category_Id] [int] NOT NULL,
	[Brand_Id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Category_Id] ASC,
	[Brand_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Brands]

-- %%
/****** Object:  Table [dbo].[Brands]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Brands](
	[Brand_Id] [int] IDENTITY(1,1) NOT NULL,
	[Brand_Name] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Brand_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cart]

-- %%
/****** Object:  Table [dbo].[Cart]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cart](
	[Cart_Id] [int] NOT NULL,
	[Create_at] [date] NOT NULL,
	[Update_at] [date] NOT NULL,
	[User_id] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Cart_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cart_detail]

-- %%
/****** Object:  Table [dbo].[Cart_detail]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cart_detail](
	[Quantity] [int] NOT NULL,
	[Cart_Item_Id] [int] NOT NULL,
	[Product_Id] [varchar](100) NOT NULL,
	[Cart_Id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Cart_Item_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Product_Id] ASC,
	[Cart_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[Category_Id] [int] IDENTITY(1,1) NOT NULL,
	[Category_Name] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Category_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comments]

-- %%
/****** Object:  Table [dbo].[Comments]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comments](
	[Comment_Id] [int] NOT NULL,
	[Content] [nvarchar](200) NOT NULL,
	[Create_at] [int] NOT NULL,
	[User_id] [varchar](100) NOT NULL,
	[Product_Id] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Comment_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Order_detail]

-- %%
/****** Object:  Table [dbo].[Order_detail]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Order_detail](
	[quantity] [int] NOT NULL,
	[price] [int] NOT NULL,
	[Order_Id] [int] NOT NULL,
	[Product_Id] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Order_Id] ASC,
	[Product_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Order_Details]

-- %%
/****** Object:  Table [dbo].[Order_Details]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Order_Details](
	[Order_Detail_Id] [int] IDENTITY(1,1) NOT NULL,
	[Order_Id] [int] NOT NULL,
	[Product_Id] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[Price] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Order_Detail_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[Order_Id] [int] NOT NULL,
	[Order_date] [date] NOT NULL,
	[Status] [int] NOT NULL,
	[User_id] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Order_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[Product_Id] [varchar](100) NOT NULL,
	[Name] [varchar](200) NOT NULL,
	[Description] [varchar](200) NULL,
	[Price] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[View] [int] NULL,
	[Brand_Id] [int] NULL,
	[Category_Id] [int] NULL,
	[Image] [varchar](max) NULL,
 CONSTRAINT [PK__Products__9834FBBA2D3EA5C5] PRIMARY KEY CLUSTERED 
(
	[Product_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 7/31/2025 2:55:15 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[User_id] [varchar](100) NOT NULL,
	[UserName] [varchar](50) NOT NULL,
	[PassWord] [varchar](50) NOT NULL,
	[Email] [varchar](100) NOT NULL,
	[FullName] [nvarchar](50) NOT NULL,
	[Phone] [varchar](13) NOT NULL,
	[Role] [varchar](30) NOT NULL,
	[Adress] [nvarchar](200) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[User_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Brand_Cat__Brand__01142BA1]

-- %%
ALTER TABLE [dbo].[Brand_Category]  WITH CHECK ADD FOREIGN KEY([Brand_Id])
REFERENCES [dbo].[Brands] ([Brand_Id])
GO

-- %% [markdown]
-- # [FK__Brand_Cat__Categ__00200768]

-- %%
ALTER TABLE [dbo].[Brand_Category]  WITH CHECK ADD FOREIGN KEY([Category_Id])
REFERENCES [dbo].[Categories] ([Category_Id])
GO

-- %% [markdown]
-- # [FK__Cart__User_id__44FF419A]

-- %%
ALTER TABLE [dbo].[Cart]  WITH CHECK ADD FOREIGN KEY([User_id])
REFERENCES [dbo].[Users] ([User_id])
GO

-- %% [markdown]
-- # [FK_Cart_Users]

-- %%
ALTER TABLE [dbo].[Cart]  WITH CHECK ADD  CONSTRAINT [FK_Cart_Users] FOREIGN KEY([User_id])
REFERENCES [dbo].[Users] ([User_id])
GO
ALTER TABLE [dbo].[Cart] CHECK CONSTRAINT [FK_Cart_Users]
GO

-- %% [markdown]
-- # [FK__Cart_deta__Cart___4D94879B]

-- %%
ALTER TABLE [dbo].[Cart_detail]  WITH CHECK ADD FOREIGN KEY([Cart_Id])
REFERENCES [dbo].[Cart] ([Cart_Id])
GO

-- %% [markdown]
-- # [FK__Cart_deta__Produ__4CA06362]

-- %%
ALTER TABLE [dbo].[Cart_detail]  WITH CHECK ADD  CONSTRAINT [FK__Cart_deta__Produ__4CA06362] FOREIGN KEY([Product_Id])
REFERENCES [dbo].[Products] ([Product_Id])
GO
ALTER TABLE [dbo].[Cart_detail] CHECK CONSTRAINT [FK__Cart_deta__Produ__4CA06362]
GO

-- %% [markdown]
-- # [FK__Comments__Produc__3F466844]

-- %%
ALTER TABLE [dbo].[Comments]  WITH CHECK ADD  CONSTRAINT [FK__Comments__Produc__3F466844] FOREIGN KEY([Product_Id])
REFERENCES [dbo].[Products] ([Product_Id])
GO
ALTER TABLE [dbo].[Comments] CHECK CONSTRAINT [FK__Comments__Produc__3F466844]
GO

-- %% [markdown]
-- # [FK__Comments__User_i__3E52440B]

-- %%
ALTER TABLE [dbo].[Comments]  WITH CHECK ADD FOREIGN KEY([User_id])
REFERENCES [dbo].[Users] ([User_id])
GO

-- %% [markdown]
-- # [FK__Order_det__Order__47DBAE45]

-- %%
ALTER TABLE [dbo].[Order_detail]  WITH CHECK ADD FOREIGN KEY([Order_Id])
REFERENCES [dbo].[Orders] ([Order_Id])
GO

-- %% [markdown]
-- # [FK__Order_det__Produ__48CFD27E]

-- %%
ALTER TABLE [dbo].[Order_detail]  WITH CHECK ADD  CONSTRAINT [FK__Order_det__Produ__48CFD27E] FOREIGN KEY([Product_Id])
REFERENCES [dbo].[Products] ([Product_Id])
GO
ALTER TABLE [dbo].[Order_detail] CHECK CONSTRAINT [FK__Order_det__Produ__48CFD27E]
GO

-- %% [markdown]
-- # [FK__Orders__User_id__4222D4EF]

-- %%
ALTER TABLE [dbo].[Orders]  WITH CHECK ADD FOREIGN KEY([User_id])
REFERENCES [dbo].[Users] ([User_id])
GO

-- %% [markdown]
-- # [FK_Products_Brands]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Brands] FOREIGN KEY([Brand_Id])
REFERENCES [dbo].[Brands] ([Brand_Id])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Brands]
GO

-- %% [markdown]
-- # [FK_Products_Categories]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Categories] FOREIGN KEY([Category_Id])
REFERENCES [dbo].[Categories] ([Category_Id])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Categories]
GO
